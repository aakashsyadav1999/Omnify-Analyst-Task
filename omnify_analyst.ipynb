# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("C:\\Users\\aakas\\OneDrive\\Documents\\VS code files\\omnify_analyst_internship_task\\Omnify-Analyst-Intership-Task.xlsx")
df.head()
# Out:
#         Week                  Campaign                            Ad group  \
# 0 2021-01-25       EK_Generic_Swimming       Pool_Reservation_System_Exact
# 1 2021-01-25       EK_Generic_Swimming              Pool_Booking_App_Exact
# 2 2021-01-25  EK_Generic_Quad-Tok_Yoga  Yoga_Studio_Booking_Software_Broad
# 3 2021-01-25       EK_Generic_Swimming     Pool_Scheduling_Software_Phrase
# 4 2021-01-25    EK_Generic_Swimming_UK     Pool_Reservation_Software_Broad
#
#   Keyword type                Search Keyword Currency  Clicks  Impressions  \
# 0        Exact       pool reservation system      USD       2           17
# 1        Exact              pool booking app      USD       1           13
# 2        Broad  yoga studio booking software      USD       4          154
# 3       Phrase      pool scheduling software      USD       2            8
# 4        Broad     pool reservation software      USD       2           13
#
#    Cost ($)  Leads  Prospects Payment ($) Payment Date Country
# ...

# %%
df.isnull().sum()
# Out:
# Week                0
# Campaign            0
# Ad group            0
# Keyword type        0
# Search Keyword      6
# Currency            0
# Clicks              0
# Impressions         0
# Cost ($)            0
# Leads               0
# Prospects           0
# Payment ($)       410
# Payment Date      410
# Country             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Week            418 non-null    datetime64[ns]
#  1   Campaign        418 non-null    object
#  2   Ad group        418 non-null    object
#  3   Keyword type    418 non-null    object
#  4   Search Keyword  412 non-null    object
#  5   Currency        418 non-null    object
#  6   Clicks          418 non-null    int64
#  7   Impressions     418 non-null    int64
#  8   Cost ($)        418 non-null    float64
#  9   Leads           418 non-null    int64
#  10  Prospects       418 non-null    int64
#  11  Payment ($)     8 non-null      object
#  12  Payment Date    8 non-null      datetime64[ns]
#  13  Country         418 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(4), object(7)
# memory usage: 45.8+ KB

# %%
class info():
    def __init__(self):
        self.df=df
    def info_(self):
        info__=df.info()
        return info__
    def is_null_sum(self):
        null_sum=df.isnull().sum()/100,("%")
        print("-----------------------------------")
        return null_sum
    def des_cribe(self):
        des=df.describe()
        print("-----------------------------------")
        return des
    def uni_que(self):
        uniquee=df.unique()
df1=info()
print(df1.info_())
print(df1.is_null_sum())
print(df1.des_cribe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Week            418 non-null    datetime64[ns]
#  1   Campaign        418 non-null    object
#  2   Ad group        418 non-null    object
#  3   Keyword type    418 non-null    object
#  4   Search Keyword  412 non-null    object
#  5   Currency        418 non-null    object
#  6   Clicks          418 non-null    int64
#  7   Impressions     418 non-null    int64
#  8   Cost ($)        418 non-null    float64
#  9   Leads           418 non-null    int64
#  10  Prospects       418 non-null    int64
#  11  Payment ($)     8 non-null      object
#  12  Payment Date    8 non-null      datetime64[ns]
#  13  Country         418 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(4), object(7)
# memory usage: 45.8+ KB
# None
# -----------------------------------
# ...

# %%
for i in df.columns:
    print(i,"------------>",df[i].unique())
# Out:
# Week ------------> ['2021-01-25T00:00:00.000000000' '2021-02-01T00:00:00.000000000'
#  '2021-02-08T00:00:00.000000000' '2021-02-15T00:00:00.000000000'
#  '2021-02-22T00:00:00.000000000' '2021-03-01T00:00:00.000000000'
#  '2021-03-08T00:00:00.000000000' '2021-03-15T00:00:00.000000000'
#  '2021-03-22T00:00:00.000000000' '2021-03-29T00:00:00.000000000'
#  '2021-04-05T00:00:00.000000000' '2021-04-12T00:00:00.000000000'
#  '2021-04-19T00:00:00.000000000' '2021-04-26T00:00:00.000000000'
#  '2021-05-03T00:00:00.000000000']
# Campaign ------------> ['EK_Generic_Swimming' 'EK_Generic_Quad-Tok_Yoga' 'EK_Generic_Swimming_UK'
#  'EK_Generic_Swimming_Canada' 'EK_Generic_Tri-Tok_Reservation'
#  'EK_Generic_Quad-Tok_Yoga_Singapore'
#  'EK_Generic_Tri-Tok_Reservation_Canada'
#  'EK_Generic_Tri-Tok_Reservation_UK' 'EK_Generic_Tri-Tok_Reservation_UAE'
#  'EK_Generic_Tri-Tok_Reservation_Singapore' 'EK_Generic_Quad-Tok_Pilates'
#  'EK_Generic_Tri-Tok_Yoga_Singapore' 'EK_Generic_Tri-Tok_Pilates'
# ...

# %%
df.columns=df.columns.str.strip()

# %%
df.head()
# Out:
#         Week                  Campaign                            Ad group  \
# 0 2021-01-25       EK_Generic_Swimming       Pool_Reservation_System_Exact
# 1 2021-01-25       EK_Generic_Swimming              Pool_Booking_App_Exact
# 2 2021-01-25  EK_Generic_Quad-Tok_Yoga  Yoga_Studio_Booking_Software_Broad
# 3 2021-01-25       EK_Generic_Swimming     Pool_Scheduling_Software_Phrase
# 4 2021-01-25    EK_Generic_Swimming_UK     Pool_Reservation_Software_Broad
#
#   Keyword type                Search Keyword Currency  Clicks  Impressions  \
# 0        Exact       pool reservation system      USD       2           17
# 1        Exact              pool booking app      USD       1           13
# 2        Broad  yoga studio booking software      USD       4          154
# 3       Phrase      pool scheduling software      USD       2            8
# 4        Broad     pool reservation software      USD       2           13
#
#    Cost ($)  Leads  Prospects Payment ($) Payment Date Country
# ...

# %%
df.columns=df.columns.str.replace("$","")
df.columns=df.columns.str.replace(" ","")
df.columns=df.columns.str.replace('(','')
df.columns=df.columns.str.replace(')','')
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\410351299.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns=df.columns.str.replace("$","")
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\410351299.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns=df.columns.str.replace('(','')
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\410351299.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns=df.columns.str.replace(')','')

# %%
df.head()
# Out:
#         Week                  Campaign                             Adgroup  \
# 0 2021-01-25       EK_Generic_Swimming       Pool_Reservation_System_Exact
# 1 2021-01-25       EK_Generic_Swimming              Pool_Booking_App_Exact
# 2 2021-01-25  EK_Generic_Quad-Tok_Yoga  Yoga_Studio_Booking_Software_Broad
# 3 2021-01-25       EK_Generic_Swimming     Pool_Scheduling_Software_Phrase
# 4 2021-01-25    EK_Generic_Swimming_UK     Pool_Reservation_Software_Broad
#
#   Keywordtype                 SearchKeyword Currency  Clicks  Impressions  \
# 0       Exact       pool reservation system      USD       2           17
# 1       Exact              pool booking app      USD       1           13
# 2       Broad  yoga studio booking software      USD       4          154
# 3      Phrase      pool scheduling software      USD       2            8
# 4       Broad     pool reservation software      USD       2           13
#
#     Cost  Leads  Prospects Payment PaymentDate Country
# ...

# %%
df['Adgroup'].unique()
# Out:
# array(['Pool_Reservation_System_Exact', 'Pool_Booking_App_Exact',
#        'Yoga_Studio_Booking_Software_Broad',
#        'Pool_Scheduling_Software_Phrase',
#        'Pool_Reservation_Software_Broad',
#        'Pool_Reservation_Software_Exact',
#        'Reservation_Management_System_Phrase',
#        'Reservation_Management_System_Exact',
#        'Swimming_Pool_Reservation_System_Exact',
#        'Yoga_Studio_Booking_Software_Exact',
#        'Swimming_Pool_Booking_System_Exact',
#        'Yoga_Studio_Generic_Software_Phrase',
#        'Pilates_Studio_Management_Software_Exact',
#        'Pool_Reservation_Software_Open_Broad',
#        'Yoga_Studio_Software_Exact', 'Pilates_Booking_System_Exact',
#        'Pilates_Studio_Software_Phrase',
#        'Pilates_Management_Software_Exact',
#        'Pilates_Studio_Software_Exact',
#        'Pilates_Studio_Booking_Software_Broad', 'Yoga_Studio_App_Phrase',
#        'Yoga_Studio_App_Broad', 'Yoga_Studio_Software_Broad',
# ...

# %%
df['Ad_group_2'] = df['Adgroup'].astype(str).str[:16]

# %%
df['Ad_group_2'].unique()
# Out:
# array(['Pool_Reservation', 'Pool_Booking_App', 'Yoga_Studio_Book',
#        'Pool_Scheduling_', 'Reservation_Mana', 'Swimming_Pool_Re',
#        'Swimming_Pool_Bo', 'Yoga_Studio_Gene', 'Pilates_Studio_M',
#        'Yoga_Studio_Soft', 'Pilates_Booking_', 'Pilates_Studio_S',
#        'Pilates_Manageme', 'Pilates_Studio_B', 'Yoga_Studio_App_'],
#       dtype=object)

# %%
df['Ad_group_2']=df['Ad_group_2'].replace("Pool_Booking_App","Pool_Booking")
df['Ad_group_2']=df['Ad_group_2'].replace("Yoga_Studio_Book","Yoga_Studio")
df['Ad_group_2']=df['Ad_group_2'].replace("Pool_Scheduling_","Pool_Scheduling")
df['Ad_group_2']=df['Ad_group_2'].replace("Swimming_Pool_Re","Swimming_Pool")
df['Ad_group_2']=df['Ad_group_2'].replace("Swimming_Pool_Bo","Swimming_Pool")
df['Ad_group_2']=df['Ad_group_2'].replace("Yoga_Studio_Gene","Yoga_Studio")
df['Ad_group_2']=df['Ad_group_2'].replace("Pilates_Studio_M","Pilates_Studio")
df['Ad_group_2']=df['Ad_group_2'].replace("Yoga_Studio_Soft","Yoga_Studio")
df['Ad_group_2']=df['Ad_group_2'].replace("Pilates_Booking_","Pilates_Booking")
df['Ad_group_2']=df['Ad_group_2'].replace("Pilates_Studio_S","Pilates_Studio")
df['Ad_group_2']=df['Ad_group_2'].replace("Pilates_Manageme","Pilates_Management")
df['Ad_group_2']=df['Ad_group_2'].replace("Pilates_Studio_B","Pilates_Studio")
df['Ad_group_2']=df['Ad_group_2'].replace("Yoga_Studio_App_","Yoga_Studio")
df['Ad_group_2']=df['Ad_group_2'].replace("Reservation_Mana","Reservation_Management")

# %%
df['Ad_group_2'].unique()
# Out:
# array(['Pool_Reservation', 'Pool_Booking', 'Yoga_Studio',
#        'Pool_Scheduling', 'Reservation_Management', 'Swimming_Pool',
#        'Pilates_Studio', 'Pilates_Booking', 'Pilates_Management'],
#       dtype=object)

# %%
df['Ad_group_3'] = df['Adgroup'].astype(str).str[-15:]
df['Ad_group_3']
# Out:
# 0      on_System_Exact
# 1      oking_App_Exact
# 2      _Software_Broad
# 3      Software_Phrase
# 4      _Software_Broad
#             ...
# 413    _Software_Broad
# 414    _Software_Exact
# 415    nt_System_Exact
# 416    _Software_Broad
# 417    _Software_Exact
# Name: Ad_group_3, Length: 418, dtype: object

# %%
df['Ad_group_3'].unique()
# Out:
# array(['on_System_Exact', 'oking_App_Exact', '_Software_Broad',
#        'Software_Phrase', '_Software_Exact', 't_System_Phrase',
#        'nt_System_Exact', 'ng_System_Exact', 'ware_Open_Broad',
#        'udio_App_Phrase', 'tudio_App_Broad', 'tudio_App_Exact',
#        'g_System_Phrase', 'e_Manager_Exact'], dtype=object)

# %%
df['Ad_group_3']=df['Ad_group_3'].replace("on_System_Exact","System_Exact")
df['Ad_group_3']=df['Ad_group_3'].replace("oking_App_Exact","App_Exact")
df['Ad_group_3']=df['Ad_group_3'].replace("_Software_Broad","Software_Broad")
df['Ad_group_3']=df['Ad_group_3'].replace("_Software_Exact","Software_Exact")
df['Ad_group_3']=df['Ad_group_3'].replace("t_System_Phrase","System_Phrase")
df['Ad_group_3']=df['Ad_group_3'].replace("nt_System_Exact","System_Exact")
df['Ad_group_3']=df['Ad_group_3'].replace("ng_System_Exact","System_Exact")
df['Ad_group_3']=df['Ad_group_3'].replace("ware_Open_Broad","Open_Broad")
df['Ad_group_3']=df['Ad_group_3'].replace("udio_App_Phrase","App_Phrase")
df['Ad_group_3']=df['Ad_group_3'].replace("tudio_App_Broad","App_Broad")
df['Ad_group_3']=df['Ad_group_3'].replace("tudio_App_Exact","App_Exact")
df['Ad_group_3']=df['Ad_group_3'].replace("g_System_Phrase","System_Phrase")
df['Ad_group_3']=df['Ad_group_3'].replace("e_Manager_Exact","Manager_Exact")

# %%
df['Ad_group_3'].unique()
# Out:
# array(['System_Exact', 'App_Exact', 'Software_Broad', 'Software_Phrase',
#        'Software_Exact', 'System_Phrase', 'Open_Broad', 'App_Phrase',
#        'App_Broad', 'Manager_Exact'], dtype=object)

# %%
df['Payment'] = df['Payment'].str.replace(',', '').str.replace('$', '').astype(float)
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\1258879735.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Payment'] = df['Payment'].str.replace(',', '').str.replace('$', '').astype(float)

# %%
df.head()
# Out:
#         Week                  Campaign                             Adgroup  \
# 0 2021-01-25       EK_Generic_Swimming       Pool_Reservation_System_Exact
# 1 2021-01-25       EK_Generic_Swimming              Pool_Booking_App_Exact
# 2 2021-01-25  EK_Generic_Quad-Tok_Yoga  Yoga_Studio_Booking_Software_Broad
# 3 2021-01-25       EK_Generic_Swimming     Pool_Scheduling_Software_Phrase
# 4 2021-01-25    EK_Generic_Swimming_UK     Pool_Reservation_Software_Broad
#
#   Keywordtype                 SearchKeyword Currency  Clicks  Impressions  \
# 0       Exact       pool reservation system      USD       2           17
# 1       Exact              pool booking app      USD       1           13
# 2       Broad  yoga studio booking software      USD       4          154
# 3      Phrase      pool scheduling software      USD       2            8
# 4       Broad     pool reservation software      USD       2           13
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Week           418 non-null    datetime64[ns]
#  1   Campaign       418 non-null    object
#  2   Adgroup        418 non-null    object
#  3   Keywordtype    418 non-null    object
#  4   SearchKeyword  412 non-null    object
#  5   Currency       418 non-null    object
#  6   Clicks         418 non-null    int64
#  7   Impressions    418 non-null    int64
#  8   Cost           418 non-null    float64
#  9   Leads          418 non-null    int64
#  10  Prospects      418 non-null    int64
#  11  Payment        8 non-null      float64
#  12  PaymentDate    8 non-null      datetime64[ns]
#  13  Country        418 non-null    object
#  14  Ad_group_2     418 non-null    object
#  15  Ad_group_3     418 non-null    object
# dtypes: datetime64[ns](2), float64(2), int64(4), object(8)
# ...

# %%
df['Payment'].fillna(0,inplace=True)

# %%
df['Returns'] = df['Payment']/df['Cost']

# %%
df.head()
# Out:
#         Week                  Campaign                             Adgroup  \
# 0 2021-01-25       EK_Generic_Swimming       Pool_Reservation_System_Exact
# 1 2021-01-25       EK_Generic_Swimming              Pool_Booking_App_Exact
# 2 2021-01-25  EK_Generic_Quad-Tok_Yoga  Yoga_Studio_Booking_Software_Broad
# 3 2021-01-25       EK_Generic_Swimming     Pool_Scheduling_Software_Phrase
# 4 2021-01-25    EK_Generic_Swimming_UK     Pool_Reservation_Software_Broad
#
#   Keywordtype                 SearchKeyword Currency  Clicks  Impressions  \
# 0       Exact       pool reservation system      USD       2           17
# 1       Exact              pool booking app      USD       1           13
# 2       Broad  yoga studio booking software      USD       4          154
# 3      Phrase      pool scheduling software      USD       2            8
# 4       Broad     pool reservation software      USD       2           13
#
# ...

# %%
sns.heatmap(data=df.corr(),annot=True)
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\3803735512.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),annot=True)
# <Axes: >

# %%
hist=df.select_dtypes(include=np.number)
sns.heatmap(data=hist)
# Out:
# <Axes: >

# %%
ax = df[['Clicks', 'Impressions', 'Cost','Leads','Prospects','Payment','Returns']].plot(kind='box', title='Boxplot')

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x=df['Clicks'],kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x=df['Impressions'],kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x=df['Cost'],kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x=df['Leads'],kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x=df['Prospects'],kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x=df['Payment'],kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x=df['Returns'],kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['Week', 'Campaign', 'Adgroup', 'Keywordtype', 'SearchKeyword',
#        'Currency', 'Clicks', 'Impressions', 'Cost', 'Leads', 'Prospects',
#        'Payment', 'PaymentDate', 'Country', 'Ad_group_2', 'Ad_group_3',
#        'Returns'],
#       dtype='object')

# %%
def count_plot_campaign_generic(data=df):
    plt.figure(figsize=(20,5))
    plot=sns.countplot(x=df['Campaign'],order=df.Campaign.value_counts().index)
    plt.xticks(rotation=90)
    return plot
count_plot_campaign_generic()
# Out:
# <Axes: xlabel='Campaign', ylabel='count'>

# %%
def count_plot_ad_group_2_generic(data=df):
    plt.figure(figsize=(20,5))
    plot=sns.countplot(x=df['Ad_group_2'],order=df.Ad_group_2.value_counts().index)
    plt.xticks(rotation=90)
    return plot
count_plot_ad_group_2_generic()
# Out:
# <Axes: xlabel='Ad_group_2', ylabel='count'>

# %%
def count_plot_ad_group_3_generic(data=df):
    plt.figure(figsize=(20,5))
    plot=sns.countplot(x=df['Ad_group_3'],order=df.Ad_group_3.value_counts().index)
    plt.xticks(rotation=90)
    return plot
count_plot_ad_group_3_generic()
# Out:
# <Axes: xlabel='Ad_group_3', ylabel='count'>

# %%
def count_plot_Keywordtype_generic(data=df):
    plt.figure(figsize=(20,5))
    plot=sns.countplot(x=df['Keywordtype'],order=df.Keywordtype.value_counts().index)
    plt.xticks(rotation=90)
    return plot
count_plot_Keywordtype_generic()
# Out:
# <Axes: xlabel='Keywordtype', ylabel='count'>

# %%
def count_plot_SearchKeyword_generic(data=df):
    plt.figure(figsize=(20,5))
    plot=sns.countplot(x=df['SearchKeyword'],order=df.SearchKeyword.value_counts().index)
    plt.xticks(rotation=90)
    return plot
count_plot_SearchKeyword_generic()
# Out:
# <Axes: xlabel='SearchKeyword', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Week', 'Campaign', 'Adgroup', 'Keywordtype', 'SearchKeyword',
#        'Currency', 'Clicks', 'Impressions', 'Cost', 'Leads', 'Prospects',
#        'Payment', 'PaymentDate', 'Country', 'Ad_group_2', 'Ad_group_3',
#        'Returns'],
#       dtype='object')

# %%
df.groupby(['Campaign'])['Cost','Returns'].sum().plot(kind='bar', label = 'Campaign ----> Cost & Return')
plt.legend()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\140975087.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Campaign'])['Cost','Returns'].sum().plot(kind='bar', label = 'Campaign ----> Cost & Return')

# %%
df_campaign=df.groupby(['Campaign'])['Cost','Returns'].sum()
df_campaign
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\3340158349.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_campaign=df.groupby(['Campaign'])['Cost','Returns'].sum()
#                                             Cost     Returns
# Campaign
# EK_Generic_Quad-Tok_Pilates               100.88    0.000000
# EK_Generic_Quad-Tok_Yoga                  822.86   49.513731
# EK_Generic_Quad-Tok_Yoga_Singapore          6.38    0.000000
# EK_Generic_Swimming                       741.26   73.184589
# EK_Generic_Swimming_Canada                 19.71    0.000000
# EK_Generic_Swimming_Singapore              29.91    0.000000
# EK_Generic_Swimming_UK                     95.21   81.327801
# EK_Generic_Tri-Tok_Pilates                 39.16    0.000000
# EK_Generic_Tri-Tok_Reservation            435.57  233.548520
# EK_Generic_Tri-Tok_Reservation_Canada     158.72    0.000000
# ...

# %%
df.groupby(['Ad_group_2'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_2 ----> Cost & Return')
plt.legend()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\1928886072.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Ad_group_2'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_2 ----> Cost & Return')

# %%
df_ad_group_2=df.groupby(['Ad_group_2'])['Cost','Returns'].sum()
df_ad_group_2
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\270736319.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_ad_group_2=df.groupby(['Ad_group_2'])['Cost','Returns'].sum()
#                           Cost     Returns
# Ad_group_2
# Pilates_Booking           0.00    0.000000
# Pilates_Management        0.00    0.000000
# Pilates_Studio          140.04    0.000000
# Pool_Booking             74.12    0.000000
# Pool_Reservation        606.10  154.512390
# Pool_Scheduling         146.56    0.000000
# Reservation_Management  776.85  233.548520
# Swimming_Pool            59.31    0.000000
# Yoga_Studio             985.70   67.606938

# %%
df.groupby(['Ad_group_3'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_3 ---> Cost & Return')
plt.legend()
plt.show()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\2374388616.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Ad_group_3'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_3 ---> Cost & Return')

# %%
df_ad_group_3=df.groupby(['Ad_group_3'])['Cost','Returns'].sum()
df_ad_group_3
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\2814462775.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_ad_group_3=df.groupby(['Ad_group_3'])['Cost','Returns'].sum()
#                     Cost     Returns
# Ad_group_3
# App_Broad          30.20    0.000000
# App_Exact          96.41    0.000000
# App_Phrase         10.63    0.000000
# Manager_Exact       0.00    0.000000
# Open_Broad         31.45    0.000000
# Software_Broad   1203.15  178.458680
# Software_Exact    127.74    0.000000
# Software_Phrase   212.22   18.093207
# System_Exact      356.18  137.527366
# System_Phrase     720.70  121.588595

# %%
df.groupby(['Ad_group_2','Ad_group_3'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_3 ---> Cost & Return')
plt.legend()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\536837002.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Ad_group_2','Ad_group_3'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_3 ---> Cost & Return')

# %%
df_ad_group_2_3=df.groupby(['Ad_group_2','Ad_group_3'])['Cost','Returns'].sum()
df_ad_group_2_3
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\161384350.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_ad_group_2_3=df.groupby(['Ad_group_2','Ad_group_3'])['Cost','Returns'].sum()
#                                           Cost     Returns
# Ad_group_2             Ad_group_3
# Pilates_Booking        System_Exact       0.00    0.000000
#                        System_Phrase      0.00    0.000000
# Pilates_Management     Software_Exact     0.00    0.000000
# Pilates_Studio         Manager_Exact      0.00    0.000000
#                        Software_Broad   100.88    0.000000
#                        Software_Exact    39.16    0.000000
#                        Software_Phrase    0.00    0.000000
# Pool_Booking           App_Exact         74.12    0.000000
# Pool_Reservation       Open_Broad        31.45    0.000000
#                        Software_Broad   307.48  128.944949
# ...

# %%
df.groupby(['Keywordtype'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_3 ---> Cost & Return')
plt.legend()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\1086995448.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Keywordtype'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_3 ---> Cost & Return')

# %%
df.groupby(['SearchKeyword'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_3 ---> Cost & Return')
plt.legend()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\709966897.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['SearchKeyword'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_3 ---> Cost & Return')

# %%
df.groupby(['Clicks'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_3 ---> Cost & Return')
plt.legend()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\3444045201.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Clicks'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_3 ---> Cost & Return')

# %%
df.groupby(['Impressions'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_3 ---> Cost & Return')
plt.legend()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\3923632480.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Impressions'])['Cost','Returns'].sum().plot(kind='bar', label = 'Ad_group_3 ---> Cost & Return')

# %%
df_daily=df.groupby('Week').agg(['sum']).reset_index()
df_daily.plot(x='Week', y='Impressions',kind="line")
plt.show()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\4094888432.py:1: FutureWarning: ['PaymentDate'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_daily=df.groupby('Week').agg(['sum']).reset_index()

# %%
df.columns
# Out:
# Index(['Week', 'Campaign', 'Adgroup', 'Keywordtype', 'SearchKeyword',
#        'Currency', 'Clicks', 'Impressions', 'Cost', 'Leads', 'Prospects',
#        'Payment', 'PaymentDate', 'Country', 'Ad_group_2', 'Ad_group_3',
#        'Returns'],
#       dtype='object')

# %%
df_daily=df.groupby('Week').agg(['sum']).reset_index()
df_daily.plot(x='Week', y='Clicks',kind="line")
plt.show()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\1287326337.py:1: FutureWarning: ['PaymentDate'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_daily=df.groupby('Week').agg(['sum']).reset_index()

# %%
df_daily=df.groupby('Week').agg(['sum']).reset_index()
df_daily.plot(x='Week', y='Cost',kind="line")
plt.show()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\3678758986.py:1: FutureWarning: ['PaymentDate'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_daily=df.groupby('Week').agg(['sum']).reset_index()

# %%
df_daily=df.groupby('Week').agg(['sum']).reset_index()
df_daily.plot(x='Week', y='Leads',kind="line")
plt.show()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\3458622832.py:1: FutureWarning: ['PaymentDate'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_daily=df.groupby('Week').agg(['sum']).reset_index()

# %%
df_daily=df.groupby('Week').agg(['sum']).reset_index()
df_daily.plot(x='Week', y='Returns',kind="line")
plt.show()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\1013514229.py:1: FutureWarning: ['PaymentDate'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_daily=df.groupby('Week').agg(['sum']).reset_index()

# %%
df['week_col'] = pd.to_datetime(df['Week'], format='%Y%m%d').dt.weekofyear
df
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\497967676.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week_col'] = pd.to_datetime(df['Week'], format='%Y%m%d').dt.weekofyear
#           Week                        Campaign  \
# 0   2021-01-25             EK_Generic_Swimming
# 1   2021-01-25             EK_Generic_Swimming
# 2   2021-01-25        EK_Generic_Quad-Tok_Yoga
# 3   2021-01-25             EK_Generic_Swimming
# 4   2021-01-25          EK_Generic_Swimming_UK
# ..         ...                             ...
# 413 2021-05-03             EK_Generic_Swimming
# 414 2021-05-03        EK_Generic_Quad-Tok_Yoga
# 415 2021-05-03  EK_Generic_Tri-Tok_Reservation
# 416 2021-05-03     EK_Generic_Quad-Tok_Pilates
# 417 2021-05-03     EK_Generic_Quad-Tok_Pilates
#
#                                       Adgroup Keywordtype  \
# 0               Pool_Reservation_System_Exact       Exact
# ...

# %%
df.rename(columns={'Week':'Date'},inplace=True)

# %%
df.groupby(['Date'])['Cost','Returns'].sum().plot()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\1918229018.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Date'])['Cost','Returns'].sum().plot()
# <Axes: xlabel='Date'>

# %%
df.groupby(['week_col'])['Cost','Returns'].sum().plot()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\1730377464.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['week_col'])['Cost','Returns'].sum().plot()
# <Axes: xlabel='week_col'>

# %%
df.groupby(['week_col'])['Cost','Returns','Prospects','Clicks'].sum()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\543886365.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['week_col'])['Cost','Returns','Prospects','Clicks'].sum()
#             Cost     Returns  Prospects  Clicks
# week_col
# 4         154.79   51.891394          2      15
# 5         192.58    0.000000          1      19
# 6         216.13   81.327801          1      21
# 7         235.30  111.959925          2      35
# 8         190.90    0.000000          1      22
# 9         141.40   23.189778          1      14
# 10        258.20    0.000000          1      34
# 11        184.36    0.000000          0      22
# 12        308.73   47.617149          4      46
# 13        172.11    0.000000          0      39
# 14        176.96    0.000000          0      29
# 15        137.21  121.588595          4      24
# 16         87.38    0.000000          1      19
# ...

# %%
df.groupby(['Date'])['Cost','Returns','Prospects','Clicks'].sum()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\2596868724.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Date'])['Cost','Returns','Prospects','Clicks'].sum()
#               Cost     Returns  Prospects  Clicks
# Date
# 2021-01-25  154.79   51.891394          2      15
# 2021-02-01  192.58    0.000000          1      19
# 2021-02-08  216.13   81.327801          1      21
# 2021-02-15  235.30  111.959925          2      35
# 2021-02-22  190.90    0.000000          1      22
# 2021-03-01  141.40   23.189778          1      14
# 2021-03-08  258.20    0.000000          1      34
# 2021-03-15  184.36    0.000000          0      22
# 2021-03-22  308.73   47.617149          4      46
# 2021-03-29  172.11    0.000000          0      39
# 2021-04-05  176.96    0.000000          0      29
# 2021-04-12  137.21  121.588595          4      24
# 2021-04-19   87.38    0.000000          1      19
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
df.groupby(['week_col'])['Clicks','Prospects'].sum().plot(kind='hist',ax=ax[0])
ax[0].set_title('weekly Clicks and Prospects')
df.groupby(['Date'])['Prospects','Clicks'].sum().plot(kind='line',ax=ax[1])
ax[1].set_title('monthly Clicks and Prospects')
plt.show()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\1511780982.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['week_col'])['Clicks','Prospects'].sum().plot(kind='hist',ax=ax[0])
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\1511780982.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Date'])['Prospects','Clicks'].sum().plot(kind='line',ax=ax[1])

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
df.groupby(['week_col'])['Clicks','Impressions'].sum().plot(kind='area',ax=ax[0])
ax[0].set_title('weekly Clicks and Impressions')
df.groupby(['Date'])['Impressions','Clicks'].sum().plot(kind='area',ax=ax[1])
ax[1].set_title('monthly Clicks and Impressions')
plt.show()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\2241779687.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['week_col'])['Clicks','Impressions'].sum().plot(kind='area',ax=ax[0])
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\2241779687.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Date'])['Impressions','Clicks'].sum().plot(kind='area',ax=ax[1])

# %%
x = df['Clicks']
y = df['Impressions']
colors = df['Clicks']
area = (3 * df['Impressions'])

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Campaign', 'Adgroup', 'Keywordtype', 'SearchKeyword',
#        'Currency', 'Clicks', 'Impressions', 'Cost', 'Leads', 'Prospects',
#        'Payment', 'PaymentDate', 'Country', 'Ad_group_2', 'Ad_group_3',
#        'Returns', 'week_col'],
#       dtype='object')

# %%
x = df['Clicks']
y = df['Prospects']
colors = df['Clicks']
area = (32 * df['Prospects'])**2

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
x = df['Clicks']
y = df['Returns']
colors = df['Clicks']
area = (32 * df['Returns'])

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
x = df['Prospects']
y = df['Returns']
colors = df['Prospects']
area = (32 * df['Returns'])

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
x = df['Clicks']
y = df['Leads']
colors = df['Clicks']
area = (32 * df['Leads'])**2

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
df_app_list=pd.read_excel('C:\\Users\\aakas\\OneDrive\\Documents\\VS code files\\omnify_analyst_internship_task\\Omnify-Analyst-Intership-Task.xlsx',sheet_name='Listing Site Data')

# %%
df_app_list.head()
# Out:
#   Product Name          Categories       Date of Report  Average Position  \
# 0       Omnify            Coaching  2020-10-20 00:00:00              13.0
# 1       Omnify        Dance Studio  2020-10-20 00:00:00              20.0
# 2       Omnify    Personal Trainer  2020-10-20 00:00:00               6.0
# 3       Omnify          Scheduling  2020-10-20 00:00:00              59.0
# 4       Omnify  Class Registration  2020-10-21 00:00:00               6.0
#
#    Clicks  Leads  Money Spent ($)   Channel        Location  Prospects Paid  \
# 0     1.0    NaN              2.0  Capterra   UNITED STATES        NaN  NaN
# 1     1.0    NaN              2.0  Capterra  UNITED KINGDOM        NaN  NaN
# 2     1.0    NaN              2.0  Capterra       SINGAPORE        NaN  NaN
# 3     1.0    NaN              2.0    GetApp   UNITED STATES        NaN  NaN
# 4     1.0    NaN              2.0  Capterra       AUSTRALIA        NaN  NaN
#
#   Paid Date
# 0       NaT
# 1       NaT
# 2       NaT
# ...

# %%
df_app_list.rename(columns = {'Money Spent ($)':'Money Spent'}, inplace = True)

# %%
df_app_list.head()
# Out:
#   Product Name          Categories       Date of Report  Average Position  \
# 0       Omnify            Coaching  2020-10-20 00:00:00              13.0
# 1       Omnify        Dance Studio  2020-10-20 00:00:00              20.0
# 2       Omnify    Personal Trainer  2020-10-20 00:00:00               6.0
# 3       Omnify          Scheduling  2020-10-20 00:00:00              59.0
# 4       Omnify  Class Registration  2020-10-21 00:00:00               6.0
#
#    Clicks  Leads  Money Spent   Channel        Location  Prospects Paid  \
# 0     1.0    NaN          2.0  Capterra   UNITED STATES        NaN  NaN
# 1     1.0    NaN          2.0  Capterra  UNITED KINGDOM        NaN  NaN
# 2     1.0    NaN          2.0  Capterra       SINGAPORE        NaN  NaN
# 3     1.0    NaN          2.0    GetApp   UNITED STATES        NaN  NaN
# 4     1.0    NaN          2.0  Capterra       AUSTRALIA        NaN  NaN
#
#   Paid Date
# 0       NaT
# 1       NaT
# 2       NaT
# 3       NaT
# 4       NaT

# %%
df_app_list.columns=df_app_list.columns.str.replace(" ","_")

# %%
df_app_list.columns
# Out:
# Index(['Product_Name', 'Categories', 'Date_of_Report', 'Average_Position',
#        'Clicks', 'Leads', 'Money_Spent', 'Channel', 'Location', 'Prospects',
#        'Paid', 'Paid_Date'],
#       dtype='object')

# %%
df_app_list['Date_of_Report']=df_app_list['Date_of_Report'].astype('datetime64[M]')
df_app_list['Date_of_Report']
# Out:
# 0      2020-10-01
# 1      2020-10-01
# 2      2020-10-01
# 3      2020-10-01
# 4      2020-10-01
#           ...
# 2086   2021-04-01
# 2087   2021-04-01
# 2088   2021-04-01
# 2089   2021-04-01
# 2090   2021-04-01
# Name: Date_of_Report, Length: 2091, dtype: datetime64[ns]

# %%
df_app_list['Paid'] = df_app_list['Paid'].str.replace(',', '').str.replace('$', '').astype(float)
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\372733560.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_app_list['Paid'] = df_app_list['Paid'].str.replace(',', '').str.replace('$', '').astype(float)

# %%
df_app_list['Returns'] = df_app_list['Paid']/df_app_list['Money_Spent']

# %%
df_app_list.groupby(['Channel'])['Money_Spent','Returns'].sum().round(2)
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\388900904.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_app_list.groupby(['Channel'])['Money_Spent','Returns'].sum().round(2)
#                  Money_Spent  Returns
# Channel
# Capterra            19461.85  2863.53
# GetApp               5449.90   170.29
# Software Advice       311.50   448.50

# %%
def count_Categories(data=df):
    plt.figure(figsize=(20,5))
    plot=sns.countplot(x=df_app_list['Categories'],order=df_app_list.Categories.value_counts().index,)
    plt.xticks(rotation=90)
    return plot
count_Categories()
# Out:
# <Axes: xlabel='Categories', ylabel='count'>

# %%
def count_Clicks(data=df):
    plt.figure(figsize=(20,5))
    plot=sns.countplot(x=df_app_list['Clicks'],order=df_app_list.Clicks.value_counts().index,)
    plt.xticks(rotation=90)
    return plot
count_Clicks()
# Out:
# <Axes: xlabel='Clicks', ylabel='count'>

# %%
def count_Leads(data=df):
    plt.figure(figsize=(20,5))
    plot=sns.countplot(x=df_app_list['Leads'],order=df_app_list.Leads.value_counts().index,)
    plt.xticks(rotation=90)
    return plot
count_Leads()
# Out:
# <Axes: xlabel='Leads', ylabel='count'>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
df_app_list.groupby(['Date_of_Report'])['Clicks','Leads'].sum().plot(kind='area',ax=ax[0])
ax[0].set_title('weekly Clicks and Impressions')
df_app_list.groupby(['Date_of_Report'])['Leads','Clicks'].sum().plot(kind='line',ax=ax[1])
ax[1].set_title('monthly Clicks and Impressions')
plt.show()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\2061738988.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_app_list.groupby(['Date_of_Report'])['Clicks','Leads'].sum().plot(kind='area',ax=ax[0])
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\2061738988.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_app_list.groupby(['Date_of_Report'])['Leads','Clicks'].sum().plot(kind='line',ax=ax[1])

# %%
df_app_list.columns
# Out:
# Index(['Product_Name', 'Categories', 'Date_of_Report', 'Average_Position',
#        'Clicks', 'Leads', 'Money_Spent', 'Channel', 'Location', 'Prospects',
#        'Paid', 'Paid_Date', 'Returns'],
#       dtype='object')

# %%
df_app_list.groupby(['Location'])['Money_Spent','Returns'].sum().plot(kind='bar', label = 'Location ----> Cost & Return')
plt.legend()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\1987263563.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_app_list.groupby(['Location'])['Money_Spent','Returns'].sum().plot(kind='bar', label = 'Location ----> Cost & Return')

# %%
df_app_list.groupby(['Categories'])['Money_Spent','Returns'].sum().plot(kind='bar', label = 'Location ----> Cost & Return')
plt.legend()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\3974841430.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_app_list.groupby(['Categories'])['Money_Spent','Returns'].sum().plot(kind='bar', label = 'Location ----> Cost & Return')

# %%
df_app_list.groupby(['Categories'])['Prospects','Leads'].sum().plot(kind='bar', label = 'Categories ----> Prospects & Leads')
plt.legend()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\1816520113.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_app_list.groupby(['Categories'])['Prospects','Leads'].sum().plot(kind='bar', label = 'Categories ----> Prospects & Leads')

# %%
df_app_list.groupby(['Location'])['Prospects','Leads'].sum().plot(kind='bar', label = 'Location ----> Prospects & Leads')
plt.legend()
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_10440\3518961947.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_app_list.groupby(['Location'])['Prospects','Leads'].sum().plot(kind='bar', label = 'Location ----> Prospects & Leads')

# %%
#to be continued.....
